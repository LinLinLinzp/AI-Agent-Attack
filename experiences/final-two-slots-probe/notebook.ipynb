# %% [markdown]
# # Final Two Slots Probe
#
# Run this Kaggle notebook before spending the last two submissions. It measures K1 replay cost and prints the projected V49/V50 candidate counts.

# %%
# %run probe.py

# %% [markdown]
# Send back the final JSON summary and the lines containing `safe_n`, `aggressive_n`, `safe_score`, and `aggressive_score` for both models.
